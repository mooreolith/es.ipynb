# %%
"https://mooreolith.github.io/graph-html/src/graph-html.mjs"

# %%
`<graph-html
  id="graph"
  style="width: 500px; height: 350px;"
  --K="1.0"
  --repulsion="1.0"
  --epsilon="0.1">
  
</graph-html>`

# %%
var graph = document.querySelector('es-notebook').shadowRoot.querySelectorAll('notebook-cell')[1].shadowRoot.querySelector('#graph');
var v1 = graph.createVertex()
var v2 = graph.createVertex()
var e1 = graph.createEdge(v1, v2)
